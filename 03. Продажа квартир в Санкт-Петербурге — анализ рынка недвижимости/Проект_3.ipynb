# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всей-базе?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# Описание данных
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt 


data = pd.read_csv('/datasets/real_estate_data.csv',sep='\t')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Много пропущенных значений в столбцах ceiling_height,is_apartment,balcony.Возможно, люди не указывали статус апартаментов, если недвижимость не является апартаментами,тоже самое с балконами,люди не отмечали балконы, потому что их нет.Не все указали параметр о высоте потолков,не посчитали нужным.Наличие балкона и статуса апартаментов может сильно повлиять на цену недвижимости,необходимо заполнить эти значения. Так же много пропусков в parks_nearest и ponds_nearest,в данном случае достаточно будет оставить столбцы parks_around3000 и ponds_around3000,и ориентироваться на них.

# %% [markdown]
# ## Предобработка данных

# %%
data = data.drop_duplicates().reset_index(drop=True)

# %%
data['balcony'] = data['balcony'].fillna(0)
data['is_apartment'] = data['is_apartment'].fillna(False)
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# При обработке пропусков в столбце балконы,заменила отсутствующие данные на 0,вероятно люди не стали заполнять данные о количестве балконов,потому что они отсутствуют. При обработке пропусков в столбце апартаменты,я выставила False, люди не поставили статус апартаментов,так как их недвижимость не является апартаментами. Соотношению апартаментов к всей недвижимости близко к реальной ситуации на рынке,апартаментов значительно меньше.Видно по данным из info().Заполнила высоту потолков медианой,есть выбросы в данных.

# %%
data['last_price'] = data['last_price'].astype('int')
data['balcony'] = data['balcony'].astype('int')
# Out:
# 0        0
# 1        2
# 2        0
# 3        0
# 4        0
#         ..
# 23694    0
# 23695    0
# 23696    0
# 23697    2
# 23698    0
# Name: balcony, Length: 23699, dtype: int64

# %% [markdown]
# Изменила тип данных на целочисленные.

# %%
data['ceiling_height']
# Out:
# 0        2.70
# 1        2.65
# 2        2.65
# 3        2.65
# 4        3.03
#          ...
# 23694    3.70
# 23695    2.65
# 23696    2.65
# 23697    3.00
# 23698    2.50
# Name: ceiling_height, Length: 23699, dtype: float64

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
data['price_square_metr'] = data['last_price'] / data['total_area']

# %% [markdown]
# Добавляем столбец с стоимостью за квадратный метр.

# %%
data['floors_total'].dropna()
# Out:
# 0        16.0
# 1        11.0
# 2         5.0
# 3        14.0
# 4        14.0
#          ...
# 23694     5.0
# 23695     5.0
# 23696     3.0
# 23697    17.0
# 23698     5.0
# Name: floors_total, Length: 23613, dtype: float64

# %%
data['floor_category'] ='другой этаж'
data['floor_category'] = data['floor_category'].where(data['floor']!= 1,'первый этаж')
data['floor_category'] = data['floor_category'].where(data['floor']!= data['floors_total'] ,'последний этаж')

# %%
data[data['floor'] == data['floors_total']]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12               10   3890000.0        54.0  2016-06-30T00:00:00      2
# 13               20   3550000.0        42.8  2017-07-01T00:00:00      2
# 23               11   2950000.0        32.0  2016-10-29T00:00:00      1
# 36               13   3790000.0        45.0  2017-01-25T00:00:00      2
# 43               13   9330000.0        48.0  2017-01-10T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23641             3   3100000.0        30.0  2018-03-28T00:00:00      1
# 23644             7   4990000.0        62.5  2018-04-26T00:00:00      2
# 23648            14  10100000.0        78.0  2017-05-12T00:00:00      3
# 23660             1   2950000.0        53.6  2018-02-01T00:00:00      2
# 23685            15   2490000.0        31.0  2019-01-24T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
data[data['floor']==1]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1                 7   3350000.0        40.4  2018-12-04T00:00:00      1
# 14                1   4400000.0        36.0  2016-06-23T00:00:00      1
# 16               11   6700000.0        82.0  2017-11-23T00:00:00      3
# 24                8   6500000.0        97.2  2015-10-31T00:00:00      2
# 28                8   4170000.0        44.0  2017-12-13T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23665            11   4250000.0        47.0  2016-05-20T00:00:00      1
# 23673             9   3100000.0        23.0  2018-03-19T00:00:00      1
# 23680            14   5000000.0        59.0  2019-04-04T00:00:00      3
# 23696            18   2500000.0        56.7  2018-02-11T00:00:00      2
# 23698             4   1350000.0        32.3  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Удаляю строки с пропусками в количестве этажей в доме,пропусков меньше 1%.

# %%
data['first_day_exposition'] =pd.to_datetime(data['first_day_exposition'])
data['weekday']=data['first_day_exposition'].dt.weekday
data['month']=data['first_day_exposition'].dt.month
data['year']=data['first_day_exposition'].dt.year

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
# 3            2.65          14.0          NaN      9         False  ...
# 4            3.03          14.0         32.0     13         False  ...
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %%
try:
    data['ratio_living_area'] = data['living_area'] / data['total_area']
except:
    data['ratio_living_area'] = NaN

# %%
try:
    data['ratio_kitchen_area'] = data['kitchen_area'] / data['total_area']
except:
    data['ratio_kitchen_area'] = NaN

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
# 3            2.65          14.0          NaN      9         False  ...
# 4            3.03          14.0         32.0     13         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  price_square_metr  \
# ...

# %% [markdown]
# В столбцах с жилой площадью и площадью кухни есть пропуски,попробовала обработать методом try-except.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.

# %%
data['total_area'].hist(range = (0,200),bins = 100)
# Out:
# <AxesSubplot:>

# %%
data['living_area'].hist(range = (0,80),bins = 100)
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].hist(range = (0,30),bins = 30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# К полученным данным, представленным на гистограмме, применимо определение «распределение Пуассона». На рынке превалируют квартиры с площадью, приближенной к 30 кВ.м. В силу того, что данное значение по СП 54.13330.2016. Является наименьшим рекомендуемым числом, применимым к определении площади квартир. Рекомендуемый диапазон площадей 1-комн кВ. Находится в пределах от 28 до 38. Жилая комната в 1-к квартире от 14 кв.м.,кухня от 5 кв.м. На гистограммах жилой площади и кухни так же видно скачок на минимально рекомендуемой площади.

# %%
data['rooms'].hist(range =(0,8) ,bins=8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Чаще всего встречаются квартиры в которых от 1 до 3 комнат.

# %%
data['ceiling_height'].hist(range = (2,4),bins = 50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# В данных о высоте потолков было большое количество пропусков,
# которое заполнила медианой,на гистограмме это значение хорошо выражено

# %%
data['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data['price_square_metr'].describe()
# Out:
# count    2.369900e+04
# mean     9.942166e+04
# std      5.030680e+04
# min      1.118349e+02
# 25%      7.658547e+04
# 50%      9.500000e+04
# 75%      1.142563e+05
# max      1.907500e+06
# Name: price_square_metr, dtype: float64

# %%
data['last_price'].hist(range = (0,20000000), bins=100)
# Out:
# <AxesSubplot:>

# %%
data['price_square_metr'].hist(range = (0,200000), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Гистограмма имеет нормальное распределение.Пик гистограммы со стоимостью квартир находится на 4млн,а пик гистограммы со стоимостью квадратного метра находится на 100 000р.

# %% [markdown]
# #### Вывод
#
# На рынке превалируют квартиры с площадью, приближенной к 30 кВ.м. В силу того, что данное значение по СП 54.13330.2016. Является наименьшим рекомендуемым числом, применимым к определении площади квартир. Рекомендуемый диапазон площадей 1-комн кВ. Находится в пределах от 28 до 38. Жилая комната в 1-к квартире от 14 кв.м.,кухня от 5 кв.м. На гистограммах жилой площади и кухни так же видно скачок на минимально рекомендуемой площади.
#
# Чаще всего встречаются квартиры в которых от 1 до 3 комнат.
# Высоту потолков заполняют очень редко.
# Пик стоимости квартир находится на 4 млн,а стоимость квадратного метра около 100 тысяч.

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].hist(range = (0,100),bins = 100)
# Out:
# <AxesSubplot:>

# %%
boxplot = data.boxplot(column=['days_exposition'])

# %%
plt.ylim(0,550)
boxplot = data.boxplot(column=['days_exposition'])

# %% [markdown]
# #### Вывод
# Выбросами можно считать,когда время продажи превышало 500 дней.Чаще всего квартиры продавались меньше чем за 100 дней. Есть значительное количество объявленний которые сняты через 45 и 60 дней

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %%
plt.ylim(0,15000000)
boxplot = data.boxplot(column=['last_price'])

# %%
data['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Диаграмма размаха,показывает что медиана находится ближе к 4.65млн,а выбросы если стоимость квартиры превышает 12 млн.

# %%
plt.ylim(0,120)
boxplot = data.boxplot(column=['total_area'])

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Диаграмма размаха показывает ,медиана находится на 52 кв,а выбросы если площадь квартиры превышает 115 кв

# %%
plt.ylim(0,20)
boxplot = data.boxplot(column=['rooms'])

# %% [markdown]
# Диаграмма размаха показывает, медиана находится на 2 комнатных квартирах, выбросы если комнат больше 6.

# %%
plt.ylim(0,30000)
boxplot = data.boxplot(column=['cityCenters_nearest'])

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Диаграмма размаха показывает,что медиана находится на 13.1 км, выбросы если удаленность от центра больше 27км.

# %%
good_data = data.query('last_price < 12000000'  and 'total_area < 110' and 'cityCenters_nearest < 27000 '  and 'days_exposition < 520' and 'rooms <= 6')

# %%
good_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23609 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23609 non-null  int64
#  1   last_price            23609 non-null  float64
#  2   total_area            23609 non-null  float64
#  3   first_day_exposition  23609 non-null  datetime64[ns]
#  4   rooms                 23609 non-null  int64
#  5   ceiling_height        23609 non-null  float64
#  6   floors_total          23523 non-null  float64
#  7   living_area           21713 non-null  float64
#  8   floor                 23609 non-null  int64
#  9   is_apartment          23609 non-null  bool
#  10  studio                23609 non-null  bool
#  11  open_plan             23609 non-null  bool
#  12  kitchen_area          21342 non-null  float64
#  13  balcony               23609 non-null  float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  float64
# ...

# %%
good_data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23609.000000  2.360900e+04  23609.000000  23609.000000    23609.000000
# mean       9.855013  6.369906e+06     59.515032      2.047905        2.722710
# std        5.678739  8.753600e+06     32.015906      1.006772        0.989427
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.600000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.735600e+06     69.200000      3.000000        2.700000
# max       50.000000  4.013000e+08    507.000000      6.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23523.000000  21713.000000  23609.000000  21342.000000  23609.000000
# mean      10.692556     33.924398      5.898429     10.518402      0.592105
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    23699.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.724358
# std        5.682529  1.088701e+07     35.654083      1.078405        0.988298
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  23699.000000
# mean      10.673824     34.457852      5.892358     10.569807      0.591080
# ...

# %% [markdown]
# Убираю из датасета выбросы.В новом датасете на 90 строк меньше.
# Из-за того что убрала выбросы по параметрам количество комнат,максимальная площадь,максимальная стоимость,удаленность от центра и количество дней ,которое висело объявление, медиана и среднее в этих параметрах в новом датасете немного сдвинулась в меньшую сторону.

# %% [markdown]
# #### Вывод
# Медиана стоимости квартир находится ближе к 4.65млн,а выбросы если стоимость квартиры превышает 12 млн.
# Медиана общей площади находится на 52 кв,а выбросы если площадь квартиры превышает 115 кв.
# Медиана количества комнат находится на 2-комнатной квартире ,а выбросы если в квартире комнат больше 6.
# Медиана удаленности от центра находится на 13.1 км, выбросы если удаленность от центра больше 27км.
#
# После удаления выбросов ,в датасете стало на 90 строк меньше,это говорит о том что,выбросов по этим параметрам было мало.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
plot1 = good_data.pivot_table(index='locality_name',values=['last_price','rooms','price_square_metr','total_area','cityCenters_nearest'],aggfunc='mean')
pd.plotting.scatter_matrix(plot1, figsize=(9, 9));

# %%
plot1.corr()
# Out:
#                      cityCenters_nearest  last_price  price_square_metr  \
# cityCenters_nearest             1.000000    0.019073          -0.104290
# last_price                      0.019073    1.000000           0.764282
# price_square_metr              -0.104290    0.764282           1.000000
# rooms                           0.191453    0.221873          -0.234838
# total_area                      0.059581    0.592164           0.010246
#
#                         rooms  total_area
# cityCenters_nearest  0.191453    0.059581
# last_price           0.221873    0.592164
# price_square_metr   -0.234838    0.010246
# rooms                1.000000    0.740317
# total_area           0.740317    1.000000

# %% [markdown]
# Корреляция Пирсона указывает на наличие линейной зависимости между количеством комнат и общей площадью, общей стоимостью и общей площадью,общей стоимостью и стоимостью квадратного метра

# %%
pivot_table_weekday =  good_data.pivot_table(index = 'weekday', values = 'price_square_metr', aggfunc =  'median')

pivot_table_weekday.plot()
# Out:
# <AxesSubplot:xlabel='weekday'>

# %%
pivot_table_weekday
# Out:
#          price_square_metr
# weekday
# 0             94667.465548
# 1             95565.389376
# 2             95454.545455
# 3             95078.548121
# 4             94608.145294
# 5             93534.393694
# 6             94501.718213

# %% [markdown]
# Стоимость квадратного метра в зависимости от дня недели. Самая высокая цена за квадратный метр зафиксирована ,если объявление выложено во вторник 95567 ,самая низкая цена в субботу 93478,разница порядка 2%

# %%
pivot_table_month = good_data.pivot_table(index = 'month', values = 'price_square_metr', aggfunc =  'median')

pivot_table_month.plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
pivot_table_month
# Out:
#        price_square_metr
# month
# 1           95200.944265
# 2           95000.000000
# 3           95200.000000
# 4           96478.873239
# 5           92857.142857
# 6           92741.935484
# 7           95000.000000
# 8           96052.631579
# 9           95548.478415
# 10          94142.857143
# 11          95552.270603
# 12          94238.400488

# %% [markdown]
# Самая низкая медианная цена зафиксирована в июне 92682,максимальная цена в апреле 96440, разница в 4%

# %%
pivot_table_year =  good_data.pivot_table(index = 'year', values = 'price_square_metr', aggfunc =  'median')

pivot_table_year.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
pivot_table_year
# Out:
#       price_square_metr
# year
# 2014      107000.000000
# 2015       93405.430281
# 2016       91666.666667
# 2017       92500.000000
# 2018       95652.173913
# 2019      103265.546659

# %% [markdown]
# На графике хорошо заметен кризис 2014 года,после 2014 стоимость квадратного метра упала почти на 14%, максимальный спад в 2016 году.С 2017 года стоимость жилья начала расти,и к 2019 году цены почти вернулись к уровню 2014 года,на 97% от прежней стоимости.

# %%
ylim=8000000
good_data.plot(x ='cityCenters_nearest',y ='price_square_metr', kind='scatter',alpha= 0.3)
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest', ylabel='price_square_metr'>

# %%
good_data['cityCenters_nearest'].corr(good_data['price_square_metr'])
# Out:
# -0.32882974164062334

# %% [markdown]
# На диаграмме можно увидеть зависимость чем дальше от центра,тем ниже стоимость. При этом корреляция не сильная и отрицательная.

# %%
pivot_table_rooms =  good_data.pivot_table(index = 'rooms', values = 'price_square_metr', aggfunc =  'mean')

pivot_table_rooms.plot()
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
pivot_table_rooms
# Out:
#        price_square_metr
# rooms
# 0          108513.114092
# 1          100818.265226
# 2           95489.659813
# 3           97151.150139
# 4          110331.605116
# 5          126750.342565
# 6          140718.807406

# %%
null_rooms = good_data[good_data['rooms']==0]
average_area = sum(null_rooms['total_area']) / len(null_rooms['total_area'])
average_area
# Out:
# 29.279746192893413

# %% [markdown]
# Исходя из таблицы и графика,самая низкая стоимость квадратного метра в 2-комнатной квартире.
# На 13.6% стоимость квадратного метра в студии превышает стоимость квадратного метра в 2-комнатной квартире.
# На 5,5% стоимость квадратного метра в 1-комнатной квартире превышает стоимость квадратного метра в 2-комнатной квартире.
# На 1,7% стоимость квадратного метра в 3-комнатной квартире превышает стоимость квадратного метра в 2-комнатной квартире.
# На 15,5% стоимость квадратного метра в 4-комнатной квартире превышает стоимость квадратного метра в 2-комнатной квартире.
# На 32,7% стоимость квадратного метра в 5-комнатной квартире превышает стоимость квадратного метра в 2-комнатной квартире.
# Самая низкая стоимость у 2-комнатных и 3-комнатных квартир. Стоимость квадратного метра у квартир где больше 4-комнат возрастает,возможно квартиры переходят в дорогой сегмент квартир.

# %%
pivot_table_floor_category =  good_data.pivot_table(index = 'floor_category', values = 'price_square_metr', aggfunc =  'median')

pivot_table_floor_category.plot()
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %%
pivot_table_floor_category
# Out:
#                 price_square_metr
# floor_category
# другой этаж          98275.862069
# первый этаж          81250.000000
# последний этаж       87378.640777

# %% [markdown]
# На стоимость квадратного метра влияет этаж квартиры. Если квартира находится не на первом и не на последнем этаже,это увеличивает ее стоимость. Квартира на первом этаже на 17,4% дешевле ,квартиры на любом этаже,кроме последнего, и на 7% дешевле чем квартира на последнем этаже.Квартира на последнем этаже дешевле квартиры на любом этаже кроме первого почти 11%

# %%
pivot_table_city_total_area = good_data.pivot_table(index = 'total_area', values = 'price_square_metr', aggfunc =  'mean')

good_data.plot(x ='total_area',y = 'price_square_metr',xlim =(0, 120), ylim =(0, 200000), kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='price_square_metr'>

# %%
pivot_table_city_total_area.plot(xlim =(20, 120),ylim =(40000, 200000))
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
pivot_table_city_total_area = good_data.pivot_table(index = 'total_area', values = 'last_price', aggfunc =  'mean')

pivot_table_city_total_area.plot(xlim =(0, 120),ylim =(0, 40000000))
# Out:
# <AxesSubplot:xlabel='total_area'>

# %% [markdown]
# Чем больше площадь квартиры,тем выше стоимость.

# %%
pivot_table_ratio_living_area = data.pivot_table(index = 'ratio_living_area', values = 'price_square_metr', aggfunc = 'mean')
data.plot(x='ratio_living_area',y ='price_square_metr', ylim=(0,300000),kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='ratio_living_area', ylabel='price_square_metr'>

# %%
pivot_table_ratio_living_area = data.pivot_table(index = 'ratio_living_area', values = 'price_square_metr', aggfunc = 'mean')
pivot_table_ratio_living_area.plot(ylim=(0,500000))
# Out:
# <AxesSubplot:xlabel='ratio_living_area'>

# %% [markdown]
# Чаще всего встречается жилая площадь занимает от 40% до 80% от общей площади.При 60% наиболее высокая стоимость квадратног метра.

# %%
studio = data[data['studio']== True]
studio['price_square_metr'].median()
# Out:
# 105555.55555555556

# %%
studio['total_area'].median()
# Out:
# 26.0

# %%
one_room = data[data['rooms']== 1]
one_room['price_square_metr'].median()
# Out:
# 100000.0

# %%
one_room['total_area'].median()
# Out:
# 36.56

# %% [markdown]
# Стоимость квадратного метра в студии на 5% дороже стоимости кв.м.в 1-комнатной квартире. Площадь студий меньше чем 1-комнатной квартиры,значит и стоимость студий будет меньше стоимости 1-комнатной квартиры,этим студии привлекательны.

# %% [markdown]
# #### Вывод
# На стоимость квадратного метра большое влияние оказывает:
# - этаж квартиры. Самый дешевый этаж- первый,чуть дороже последний, любые другие этаж выше по стоимости.
# - удаленность от центра
# - год продажи
# - комнатность квартиры.Низкая стоимость квадратного метра у 2 и 3 комнатных квартир. При этом стоимость квадратного метра в  студии на 5% дороже чем в 1-комнатной квартире.
# - отношение жилой площади к общей площади,самая высокая стоимость ,если отношение 6/10.

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
locality = good_data.pivot_table(index = 'locality_name',values = 'price_square_metr',aggfunc = ['mean','count','median'])
locality.columns = ['mean','count','median']
locality = locality.sort_values('count',ascending=False)
top_locality =locality[:10] 
top_locality
# Out:
#                             mean  count         median
# locality_name
# Санкт-Петербург    114595.039970  15634  104761.904762
# посёлок Мурино      85752.189195    522   85878.462169
# посёлок Шушары      78677.364217    440   76876.172608
# Всеволожск          68654.473986    398   65789.473684
# Пушкин             103100.890905    368   99993.589744
# Колпино             75333.295801    337   74722.222222
# посёлок Парголово   90332.263023    326   91780.224134
# Гатчина             68746.146763    307   67796.610169
# деревня Кудрово     92473.547576    299   91860.465116
# Выборг              58141.909153    237   58158.319871

# %%
top_locality[top_locality['mean']==top_locality['mean'].min()]
# Out:
#                        mean  count        median
# locality_name
# Выборг         58141.909153    237  58158.319871

# %%
top_locality[top_locality['mean']==top_locality['mean'].max()]
# Out:
#                          mean  count         median
# locality_name
# Санкт-Петербург  114595.03997  15634  104761.904762

# %% [markdown]
# #### Вывод
# Самые высокая стоимость квадратного метра у Санкт-Петербурга.Самая низкая стоимость из выборки топ10 по количеству объявление будет у Выборга.

# %% [markdown]
#  ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
data.loc[:,'cityCenters_nearest_km'] = data.loc[:,'cityCenters_nearest']/1000

# %%
data.loc[:,'cityCenters_nearest_km'] = data.loc[:,'cityCenters_nearest_km'].fillna(-1).astype('int')

# %%
data_center = data.query('locality_name == "Санкт-Петербург" and cityCenters_nearest_km != -1')

# %%
pivot_table_km = data_center.pivot_table(index ='cityCenters_nearest_km' , values = 'price_square_metr', aggfunc = 'median' )
pivot_table_km.plot(xlim = (0,30))
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest_km'>

# %% [markdown]
# #### Вывод
# Попробую предположить,резкая смена графика идет на 3км,это и будет являться центром Санкт-Петербурга.

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %%
locality_center = data.query('cityCenters_nearest_km <= 3 and locality_name == "Санкт-Петербург"')

# %%
locality_center['total_area'].hist(range=(0,200),bins = 50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме с центром Санкт-Петербурга пик находится на 75 кв.м.На гистограмме со всем датасетом пик находился около 40 кв.м.Квартиры в центре Санкт-Петербурга имеют большую площадь по сравнению с отдаленными районами.

# %%
locality_center['rooms'].hist(range=(0,8),bins=8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме с центром Санкт-Петербурга пик находится на 3 комнатах.На гистограмме со всем датасетом пик находился 1-комнатных и 2-комнатных квартирах.Квартиры в центре Санкт-Петербурга имеют больше комнат,по сравнению с отдалеными районами.

# %%
locality_center['ceiling_height'].hist(range=(2,4),bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме ,со срезом центра Санкт-Петербурга,виден пик на данных ,которые заполнили вместо пропусков. Так же много квартир с 3м. и 3 м.20 см. В центре Санкт-Петербурга больше процент квартир с потолками выше 3 метров.

# %%
locality_center['last_price'].hist(range=(0,20000000),bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме для центра Санкт-Петербурга, можно увидеть пик на 7,5 млн.На гистограмме для всего датасета пик был около 3,5 млн.Можно предположить что квартиры в центре дороже из-за расположения, а так же в центре квартиры большей площади.

# %%
locality_center['price_square_metr'].hist(range=(60000,200000),bins=100)
# Out:
# <AxesSubplot:>

# %%
locality_center['price_square_metr'].describe()
# Out:
# count    1.220000e+03
# mean     1.464922e+05
# std      1.231666e+05
# min      2.891963e+04
# 25%      9.541903e+04
# 50%      1.163849e+05
# 75%      1.512943e+05
# max      1.907500e+06
# Name: price_square_metr, dtype: float64

# %%
locality_center['last_price'].describe()
# Out:
# count    1.220000e+03
# mean     1.600610e+07
# std      3.239637e+07
# min      2.100000e+06
# 25%      6.950000e+06
# 50%      9.500000e+06
# 75%      1.449250e+07
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data['price_square_metr'].describe()
# Out:
# count    2.369900e+04
# mean     9.942166e+04
# std      5.030680e+04
# min      1.118349e+02
# 25%      7.658547e+04
# 50%      9.500000e+04
# 75%      1.142563e+05
# max      1.907500e+06
# Name: price_square_metr, dtype: float64

# %% [markdown]
# Медиана стоимость квадратного метра в центре находится на 116 000,медиана всего дата сета на 95000.Квартиры в центре на 22% дороже средней цены всего датасета .75% квартир в центре имеют стоимость кв.м. до 151,3 тысяч рублей. 75% квартир всего датасета имеют стоимость кв.м. до 114,3 тысяч рублей.При этом максимум у них одинаковый,так как центральный район включен в датасет.Минимум могут быть ошибочными.

# %%
locality_center_rooms = locality_center.pivot_table(index='rooms', values='price_square_metr',aggfunc = 'mean')
locality_center_rooms.plot(xlim=(0,5),ylim=(0,200000))
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
locality_center_cityCenters_nearest = locality_center.pivot_table(index='cityCenters_nearest_km', values='price_square_metr',aggfunc = 'mean')
locality_center_cityCenters_nearest.plot(xlim=(0,5))
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest_km'>

# %% [markdown]
# На графике можно увидеть как зависит стоимость кв.м. квартиры от удаленности от центра.

# %%
locality_center_cityCenters_year = locality_center.pivot_table(index='year', values='price_square_metr',aggfunc = 'mean')
locality_center_cityCenters_year.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
locality_center_cityCenters_year
# Out:
#       price_square_metr
# year
# 2014      253598.687261
# 2015      154054.776299
# 2016      138191.964184
# 2017      143111.137276
# 2018      139909.510681
# 2019      166166.467719

# %% [markdown]
# В отличие от всего датасета,стоимость кв.м. в центре Санкт-Петербурга к 2019 году не вернулась к стоимости 2014 года. 65,5 % от стоимости 2014 года.Всего падение было на 45%.

# %% [markdown]
# Возьмем выборку где удаленность от центра до 8км.При этом, можно не сомневаться, что квартиры с удаленностью до 3 км являются центром.Сравним новый датасет с предыдущим и с общим датасетами.

# %%
locality2_center = data.query('cityCenters_nearest_km <= 8 and locality_name == "Санкт-Петербург"')

# %%
locality2_center['total_area'].hist(range=(0,200),bins = 50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме пик находится около 45 кв.м.Если центр обозначить до 3,пик был на 75 кв.м.,из этого следует что квартиры с удаленностью от центра от 3 до 8 км часто имеют квадратуру до 50 кв.,что больше похоже на общий датасет,чем на самый центр.

# %%
locality2_center['rooms'].hist(range=(0,8),bins=8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Пик находится на 3-комнатных квартирах,в этом случае новый датасет похож на датасет с удаленностью от центра меньше 3 км.

# %%
locality2_center['ceiling_height'].hist(range=(2,4),bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Пик так же на медиане,которой мы заменяли пропущенные значения. Так же видно, что много квартир с высотой потолков равной 3 метрам и выше.

# %%
locality2_center['last_price'].hist(range=(0,20000000),bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Пики общей стоимости находится на 5.5 млн. и 6.5 млн,стоимость квартир дешевле,относительно предыдущего датасета,с удаленностью до 3 км. Это можно объяснить меньшей квадратурой квартиры,большей удаленностью от центра.

# %%
locality2_center['price_square_metr'].hist(range=(60000,200000),bins=100)
# Out:
# <AxesSubplot:>

# %%
locality2_center['price_square_metr'].describe()
# Out:
# count    4.443000e+03
# mean     1.409740e+05
# std      8.616514e+04
# min      1.534527e+04
# 25%      9.961179e+04
# 50%      1.222494e+05
# 75%      1.523947e+05
# max      1.907500e+06
# Name: price_square_metr, dtype: float64

# %% [markdown]
# Медианная стоимость квадратного метра около 122 тысяч,что на 28% дороже общего датасета и на 5% датасета с удаленностью до 3км,в locality_center около 116 тысяч. На графике с зависимостью стоимости кв.м. и удаленностью от центра виден рост после 3км.

# %%
locality2_center['last_price'].describe()
# Out:
# count    4.443000e+03
# mean     1.379518e+07
# std      2.292399e+07
# min      1.600000e+06
# 25%      6.200000e+06
# 50%      8.700000e+06
# 75%      1.350000e+07
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
locality2_center_cityCenters_nearest = locality2_center.pivot_table(index='cityCenters_nearest_km', values='price_square_metr',aggfunc = 'mean')
locality2_center_cityCenters_nearest.plot(xlim=(0,8))
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest_km'>

# %%
locality2_center_cityCenters_year = locality2_center.pivot_table(index='year', values='price_square_metr',aggfunc = 'mean')
locality2_center_cityCenters_year.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
locality2_center_cityCenters_year
# Out:
#       price_square_metr
# year
# 2014      179151.478132
# 2015      142285.396227
# 2016      142267.222019
# 2017      139000.979158
# 2018      136975.634528
# 2019      152184.701703

# %% [markdown]
# В отличие от всего датасета,стоимость кв.м. в центре Санкт-Петербурга к 2019 году не вернулась к стоимости 2014 года. 85 % от стоимости 2014 года.Всего падение было на 24%, и в 2018 году,что не похоже на общий датасет и locality_center.

# %% [markdown]
# Сделаем новую выборку с удаленность от 3 до 8 км

# %%
locality3_center= data.query('cityCenters_nearest_km <= 8 and cityCenters_nearest_km > 3 and locality_name == "Санкт-Петербург"')

# %%
locality3_center_cityCenters_year = locality3_center.pivot_table(index='year', values='price_square_metr',aggfunc = 'mean')

# %%
locality3_center_cityCenters_year
# Out:
#       price_square_metr
# year
# 2014      156047.171850
# 2015      136730.248834
# 2016      143634.819806
# 2017      137453.327028
# 2018      135938.435015
# 2019      145914.327529

# %% [markdown]
# #### Вывод
# Тяжело определится с центром Санкт-Петербурга,locality2_center имеет схожие параметры с общим датасетом и с locality_center. Удаленность от 3 до 8 км я бы выделила в отдельную категорию,а центр оставила в радиусе до 3 км.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В среднем квартиры продаются быстрее чем за 100 дней,много объявлений снято после 45 дней или 60 дней.
# На стоимость квартиры влияют такие параметры:
#     Число комнат,двух или трехкомнатые квартиры дешевле.
#     Удаленность от центра
#     Этаж квартиры,дешевле квартиры на первом этаже.
#     Год продажи квартиры.После 2014 начался кризис,стоимость квартир потянулась вниз.При этом стоимость квартир в отдаленных районах к 2019 году почти вернулась к уровню 2014 года,а стоимость квартир в центре в 2019 году,стоила 66% от 2014 года.

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
